# %%
import os
os.listdir()
# Out:
# ['data.txt',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'Без названия.ipynb']

# %%
import pandas
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv('supermarkets-semi-colons.txt', sep=';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pandas.read_csv('data.txt', header=None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns = ["ID","Address", "City", "ZIP", "Country", "Name", "Employees"]
df6
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = df6.set_index("ID")
df7
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index("Name", inplace=True, drop=False)
df6
# Out:
#              ID          Address           City               ZIP Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df7.loc['3':'4',"City":"Country"]
# Out:
#              City               ZIP Country
# ID
# 3   San Francisco  California 94114     USA
# 4   San Francisco          CA 94114     USA

# %%
df6.loc["Sanchez","Employees"]
# Out:
# 12

# %%
list(df7.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df7.iloc[:,0:3]
# Out:
#             Address           City               ZIP
# ID
# 1      3666 21st St  San Francisco          CA 94114
# 2    735 Dolores St  San Francisco          CA 94119
# 3       332 Hill St  San Francisco  California 94114
# 4      3995 23rd St  San Francisco          CA 94114
# 5   1056 Sanchez St  San Francisco        California
# 6   551 Alvarado St  San Francisco          CA 94114

# %%
df7.drop(1,0)
# Out:
# /tmp/ipykernel_11919/2150799874.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(1,0)
#             Address           City               ZIP Country         Name  \
# ID
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.drop(df7.index[0:3],0)
# Out:
# /tmp/ipykernel_11919/4142530650.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.index[0:3],0)
#             Address           City         ZIP Country        Name  Employees
# ID
# 4      3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop         10
# 5   1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7.drop(df7.columns[0:3],1)
# Out:
# /tmp/ipykernel_11919/2806056389.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.columns[0:3],1)
#    Country         Name  Employees
# ID
# 1      USA      Madeira          8
# 2      USA  Bready Shop         15
# 3      USA  Super River         25
# 4      USA   Ben's Shop         10
# 5      USA      Sanchez         12
# 6      USA   Richvalley         20

# %%
df7.drop("City",1)
# Out:
# /tmp/ipykernel_11919/3298495432.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop("City",1)
#             Address               ZIP Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
help(df7.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel' = None, axis: 'Axis' = 0, index: 'IndexLabel' = None, columns: 'IndexLabel' = None, level: 'Level' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the `user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
help(df7.loc)
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Access a group of rows and columns by label(s) or a boolean array.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'``.
#  |
#  |    .. warning:: Note that contrary to usual python slices, **both** the
#  |        start and the stop are included
#  |
#  |  - A boolean array of the same length as the axis being sliced,
#  |    e.g. ``[True, False, True]``.
#  |  - An alignable boolean Series. The index of the key will be aligned before
#  |    masking.
# ...

# %%
df7['Continent']=df7.shape[0]*['North America']
df7
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df7['Continent'] = df7['Country'] + ', ' + "North America"

# %%
df7
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees           Continent
# ID
# 1           8  USA, North America
# 2          15  USA, North America
# 3          25  USA, North America
# 4          10  USA, North America
# 5          12  USA, North America
# 6          20  USA, North America

# %%
df7_t = df7.T
df7_t
# Out:
# ID                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# ZIP                  CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ZIP                  CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
nom.geocode("Sof'i Perovskoy Ulitsa, 22, Taganrog")
# Out:
# Location(ulitsa Sof'i Perovskoy, 22, Taganrog, Rostovskaya oblast', 347909, (47.25916000886781, 38.940630014492484, 0.0))

# %%
df7["Address"] = df7["Address"] + ", " + df7["City"] + ", " + df7["ZIP"] + ", " + df7['Country']

# %%
df7["Coordinates"] = df7["Address"].apply(nom.geocode)

# %%
df7
# Out:
#                                               Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114, USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California, USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#                  ZIP Country         Name  Employees           Continent  \
# ID
# 1           CA 94114     USA      Madeira          8  USA, North America
# 2           CA 94119     USA  Bready Shop         15  USA, North America
# 3   California 94114     USA  Super River         25  USA, North America
# 4           CA 94114     USA   Ben's Shop         10  USA, North America
# 5         California     USA      Sanchez         12  USA, North America
# ...

# %%
df7.Coordinates[1].latitude
# Out:
# 37.756632001957215

# %%
df7["Latitude"] = df7["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df7["Longitude"] = df7["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df7
# Out:
#                                               Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114, USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California, USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#                  ZIP Country         Name  Employees           Continent  \
# ID
# 1           CA 94114     USA      Madeira          8  USA, North America
# 2           CA 94119     USA  Bready Shop         15  USA, North America
# 3   California 94114     USA  Super River         25  USA, North America
# 4           CA 94114     USA   Ben's Shop         10  USA, North America
# 5         California     USA      Sanchez         12  USA, North America
# ...
